# %% [markdown]
# ## First star

# %%
import sys
import copy
import re

# %%
sys.path.append("../")

# %%
file_path = 'input_ag.txt'

# %%
starting_series = []
with open(file_path, 'r') as file:
    for line in file:
        starting_series.append(line.strip('\n'))

# %%
starting_series = starting_series[0]

# %%
raw_expanded_series = copy.deepcopy(starting_series)

# %%
example_series = '125 17'

# %%
def find_numbers(series):
    numbers = re.findall(r'\d+', series)
    return numbers

# %%
def expand_series(series):
    expanded_series = []
    numbers = find_numbers(series)
    
    for number in numbers:
        if number == str(0):
            expanded_series.append('1')
            expanded_series.append(' ')
        elif len(str(number)) % 2 == 0:
            left_part = str(number)[:len(str(number)) // 2]
            right_part = str(number)[len(str(number)) // 2:]
            expanded_series.append(left_part)
            expanded_series.append(' ')
            right_part = right_part.lstrip('0')
            if len(right_part)==0:
                expanded_series.append('0')
                expanded_series.append(' ')
            else:
                expanded_series.append(right_part)
                expanded_series.append(' ')
        else:
            expanded_series.append(str(int(number) * 2024))
            expanded_series.append(' ')
    
    return ''.join(expanded_series)

# %%
expanded_series = raw_expanded_series
for i in range(25): 
    expanded_series = expand_series(expanded_series)
expanded_series
# Out:
# '12144 1 14168 4048 8096 1 8096 16192 28 67 60 32 28 67 60 32 8096 1 8096 16192 24 57 94 56 3 2 7 7 2 6 16192 80 96 2024 80 96 32772608 4048 1 4048 8096 80 96 2024 80 96 32772608 32772608 2024 36869184 24579456 12144 1 14168 4048 24 57 94 56 32 77 26 8 24 57 94 56 36 86 91 84 4048 1 4048 8096 32 77 26 8 16192 1 18216 12144 8096 1 8096 16192 16192 1 18216 12144 20 48 28 80 28 67 60 32 36 86 91 84 16192 1 18216 12144 20 48 28 80 24 57 94 56 24 57 94 56 2 0 2 4 28 67 60 32 8096 1 8096 16192 16192 1 18216 12144 2 0 2 4 16192 1 18216 12144 32 77 26 8 40 48 32772608 24579456 28676032 24579456 2024 60 72 40 48 40 48 32772608 24579456 28676032 24579456 2024 60 72 40 48 16192 1 18216 12144 2 0 2 4 16192 1 18216 12144 32 77 26 8 40 48 80 96 20482880 28676032 36869184 80 96 20482880 24579456 6 0 7 2 4 0 4 8 2867 6032 2867 6032 4 0 4 8 2457 9456 32 77 26 8 16192 1 18216 12144 2 0 2 4 16192 1 18216 12144 32 77 26 8 4 0 4 8 20 24 4 0 4 8 8 0 9 6 32 77 26 8 2 0 2 4 36 86 91 84 24 57 94 56 60 72 40 48 28676032 28676032 40 48 24579456 3277 2608 16192 1 18216 12144 2 0 2 4 16192 1 18216 12144 32 77 26 8 60 72 40 48 28676032 28676032 40 48 24579456 3277 2608 60 72 40 48 28676032 28676032 40 48 24579456 3277 2608 4 0 4 8 20 24 4 0 4 8 8 0 9 6 24 57 94 56 2 0 2 4 28 67 60 32 8096 1 8096 16192 16192 1 18216 12144 2 0 2 4 16192 1 18216 12144 32 77 26 8 40 48 32772608 24579456 28676032 24579456 2024 60 72 40 48 40 48 32772608 24579456 28676032 24579456 2024 60 72 40 48 16192 1 18216 12144 2 0 2 4 16192 1 18