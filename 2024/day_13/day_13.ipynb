# %%
import sys
import re
from math import gcd

# %%
sys.path.append("../")

# %%
file_path = 'input_ag.txt'

# %%
with open(file_path, 'r') as file:
    buttons_config = file.read()

# %%
def parse_input(input_string):
    """
    Parses the input string into a list of claw machines.
    """
    machines = []
    # Split the input into lines and remove any leading/trailing whitespace
    lines = [line.strip() for line in input_string.strip().split('\n') if line.strip()]
    
    # Process lines in chunks of 3 (Button A, Button B, Prize)
    for i in range(0, len(lines), 3):
        a_line = lines[i]
        b_line = lines[i+1]
        prize_line = lines[i+2]

        # Parse Button A
        a_match = re.match(r'Button A:\s*X\+(\d+),\s*Y\+(\d+)', a_line)
        a_x = int(a_match.group(1))
        a_y = int(a_match.group(2))

        # Parse Button B
        b_match = re.match(r'Button B:\s*X\+(\d+),\s*Y\+(\d+)', b_line)
        b_x = int(b_match.group(1))
        b_y = int(b_match.group(2))

        # Parse Prize
        prize_match = re.match(r'Prize:\s*X=(\d+),\s*Y=(\d+)', prize_line)
        prize_x = int(prize_match.group(1))
        prize_y = int(prize_match.group(2))

        machine = {
            'button_a': {'x': a_x, 'y': a_y},
            'button_b': {'x': b_x, 'y': b_y},
            'prize': {'x': prize_x, 'y': prize_y}
        }

        machines.append(machine)

    return machines

def find_min_tokens(machine, max_presses=100):
    """
    Finds the minimal token cost to win the prize for a single machine.
    """
    a_x = machine['button_a']['x']
    a_y = machine['button_a']['y']
    b_x = machine['button_b']['x']
    b_y = machine['button_b']['y']
    prize_x = machine['prize']['x']
    prize_y = machine['prize']['y']

    min_tokens = None

    # Iterate over possible x presses (Button A)
    for x in range(0, max_presses + 1):
        # Calculate remaining X distance after pressing Button A x times
        rem_x = prize_x - a_x * x

        # If Button B does not contribute to X movement
        if b_x == 0:
            if rem_x != 0:
                continue  # Cannot achieve Prize X with current x
            y_values = range(0, max_presses + 1)  # y can be any value from 0 to max_presses
        else:
            if rem_x < 0:
                continue  # Negative y presses not possible
            if rem_x % b_x != 0:
                continue  # y must be integer
            y = rem_x // b_x
            if y < 0 or y > max_presses:
                continue  # y out of allowed range
            y_values = [y]

        for y in y_values:
            # Check if Y movement matches
            total_y = a_y * x + b_y * y
            if total_y == prize_y:
                tokens = 3 * x + y
                if (min_tokens is None) or (tokens < min_tokens):
                    min_tokens = tokens

    return min_tokens

def calculate_min_tokens(input_string, max_presses=100):
    """
    Calculates the minimal total tokens required to win all possible prizes.
    """
    machines = parse_input(input_string)
    total_tokens = 0
    winnable_prizes = 0

    for idx, machine in enumerate(machines, 1):
        min_tokens = find_min_tokens(machine, max_presses)
        if min_tokens is not None:
            total_tokens += min_tokens
            winnable_prizes += 1
            print(f"Machine {idx}: Can be solved with {min_tokens} tokens.")
        else:
            print(f"Machine {idx}: Cannot be solved.")

    print(f"\nTotal winnable prizes: {winnable_prizes}")
    print(f"Total tokens needed: {total_tokens}")

    return total_tokens

# %%
input_string = """
Button A: X+94, Y+34
Button B: X+22, Y+67
Prize: X=8400, Y=5400

Button A: X+26, Y+66
Button B: X+67, Y+21
Prize: X=12748, Y=12176

Button A: X+17, Y+86
Button B: X+84, Y+37
Prize: X=7870, Y=6450

Button A: X+69, Y+23
Button B: X+27, Y+71
Prize: X=18641, Y=10279
"""

# Calculate minimal total tokens
total_tokens = calculate_min_tokens(input_string)
# Out:
# Machine 1: Can be solved with 280 tokens.
# Machine 2: Cannot be solved.
# Machine 3: Can be solved with 200 tokens.
# Machine 4: Cannot be solved.
#
# Total winnable prizes: 2
# Total tokens needed: 480

# %%
calculate_min_tokens(buttons_config)
# Out:
# Machine 1: Can be solved with 220 tokens.
# Machine 2: Can be solved with 231 tokens.
# Machine 3: Can be solved with 294 tokens.
# Machine 4: Can be solved with 273 tokens.
# Machine 5: Cannot be solved.
# Machine 6: Can be solved with 220 tokens.
# Machine 7: Cannot be solved.
# Machine 8: Cannot be solved.
# Machine 9: Can be solved with 167 tokens.
# Machine 10: Can be solved with 250 tokens.
# Machine 11: Cannot be solved.
# Machine 12: Can be solved with 213 tokens.
# Machine 13: Cannot be solved.
# Machine 14: Cannot be solved.
# Machine 15: Cannot be solved.
# Machine 16: Can be solved with 188 tokens.
# Machine 17: Cannot be solved.
# Machine 18: Cannot be solved.
# Machine 19: Cannot be solved.
# Machine 20: Can be solved with 156 tokens.
# Machine 21: Can be solved with 289 tokens.
# Machine 22: Can be solved with 284 tokens.
# Machine 23: Can be solved with 282 tokens.
# Machine 24: Cannot be solved.
# Machine 25: Can be solved with 80 tokens.
# Machine 26: Can be solved with 205 tokens.
# Machine 27: Cannot be solved.
# Machine 28: Cannot be solved.
# Machine 29: Can be solved with 137 tokens.
# Machine 30: Can be solved with 110 tokens.
# Machine 31: Can be solved with 248 tokens.
# Machine 32: Cannot be solved.
# Machine 33: Can be solved with 127 tokens.
# Machine 34: Can be solved with 173 tokens.
# Machine 35: Can be solved with 156 tokens.
# Machine 36: Cannot be solved.
# Machine 37: Can be solved with 292 tokens.
# Machine 38: Cannot be solved.
# Machine 39: Cannot be solved.
# Machine 40: Can be solved with 126 tokens.
# Machine 41: Can be solved with 176 tokens.
# Machine 42: Can be solved with 321 tokens.
# Machine 43: Cannot be solved.
# Machine 44: Can be solved with 302 tokens.
# Machine 45: Can be solved with 40 tokens.
# Machine 46: Can be solved with 109 tokens.
# Machine 47: Cannot be solved.
# Machine 48: Cannot be solved.
# Machine 49: Can be solved with 290 tokens.
# Machine 50: Cannot be solved.
# Machine 51: Can be solved with 283 tokens.
# Machine 52: Cannot be solved.
# Machine 53: Can be solved with 159 tokens.
# Machine 54: Can be solved with 90 tokens.
# Machine 55: Can be solved with 86 tokens.
# Machine 56: Can be solved with 53 tokens.
# Machine 57: Cannot be solved.
# Machine 58: Cannot be solved.
# Machine 59: Can be solved with 163 tokens.
# Machine 60: Can be solved with 201 tokens.
# Machine 61: Can be solved with 129 tokens.
# Machine 62: Cannot be solved.
# Machine 63: Cannot be solved.
# Machine 64: Cannot be solved.
# Machine 65: Can be solved with 79 tokens.
# Machine 66: Cannot be solved.
# Machine 67: Cannot be solved.
# Machine 68: Can be solved with 77 tokens.
# Machine 69: Cannot be solved.
# Machine 70: Cannot be solved.
# Machine 71: Can be solved with 93 tokens.
# Machine 72: Can be solved with 291 tokens.
# Machine 73: Can be solved with 107 tokens.
# Machine 74: Cannot be solved.
# Machine 75: Can be solved with 66 tokens.
# Machine 76: Cannot be solved.
# Machine 77: Cannot be solved.
# Machine 78: Can be solved with 306 tokens.
# Machine 79: Cannot be solved.
# Machine 80: Can be solved with 169 tokens.
# Machine 81: Can be solved with 309 tokens.
# Machine 82: Cannot be solved.
# Machine 83: Can be solved with 104 tokens.
# Machine 84: Cannot be solved.
# Machine 85: Can be solved with 277 tokens.
# Machine 86: Can be solved with 197 tokens.
# Machine 87: Cannot be solved.
# Machine 88: Can be solved with 313 tokens.
# Machine 89: Can be solved with 187 tokens.
# Machine 90: Cannot be solved.
# Machine 91: Cannot be solved.
# Machine 92: Cannot be solved.
# Machine 93: Cannot be solved.
# Machine 94: Cannot be solved.
# Machine 95: Cannot be solved.
# Machine 96: Cannot be solved.
# Machine 97: Cannot be solved.
# Machine 98: Can be solved with 258 tokens.
# Machine 99: Cannot be solved.
# Machine 100: Can be solved with 49 tokens.
# Machine 101: Can be solved with 114 tokens.
# Machine 102: Cannot be solved.
# Machine 103: Cannot be solved.
# Machine 104: Cannot be solved.
# Machine 105: Cannot be solved.
# Machine 106: Can be solved with 132 tokens.
# Machine 107: Cannot be solved.
# Machine 108: Cannot be solved.
# Machine 109: Can be solved with 99 tokens.
# Machine 110: Cannot be solved.
# Machine 111: Can be solved with 212 tokens.
# Machine 112: Cannot be solved.
# Machine 113: Cannot be solved.
# Machine 114: Cannot be solved.
# Machine 115: Cannot be solved.
# Machine 116: Cannot be solved.
# Machine 117: Can be solved with 293 tokens.
# Machine 118: Can be solved with 147 tokens.
# Machine 119: Cannot be solved.
# Machine 120: Cannot be solved.
# Machine 121: Cannot be solved.
# Machine 122: Can be solved with 301 tokens.
# Machine 123: Can be solved with 259 tokens.
# Machine 124: Cannot be solved.
# Machine 125: Can be solved with 42 tokens.
# Machine 126: Cannot be solved.
# Machine 127: Can be solved with 125 tokens.
# Machine 128: Can be solved with 96 tokens.
# Machine 129: Cannot be solved.
# Machine 130: Cannot be solved.
# Machine 131: Cannot be solved.
# Machine 132: Cannot be solved.
# Machine 133: Cannot be solved.
# Machine 134: Can be solved with 140 tokens.
# Machine 135: Can be solved with 234 tokens.
# Machine 136: Cannot be solved.
# Machine 137: Cannot be solved.
# Machine 138: Cannot be solved.
# Machine 139: Can be solved with 113 tokens.
# Machine 140: Can be solved with 93 tokens.
# Machine 141: Cannot be solved.
# Machine 142: Can be solved with 205 tokens.
# Machine 143: Cannot be solved.
# Machine 144: Can be solved with 127 tokens.
# Machine 145: Cannot be solved.
# Machine 146: Cannot be solved.
# Machine 147: Can be solved with 257 tokens.
# Machine 148: Can be solved with 221 tokens.
# Machine 149: Cannot be solved.
# Machine 150: Can be solved with 357 tokens.
# Machine 151: Can be solved with 49 tokens.
# Machine 152: Cannot be solved.
# Machine 153: Cannot be solved.
# Machine 154: Cannot be solved.
# Machine 155: Can be solved with 138 tokens.
# Machine 156: Cannot be solved.
# Machine 157: Can be solved with 130 tokens.
# Machine 158: Can be solved with 239 tokens.
# Machine 159: Cannot be solved.
# Machine 160: Cannot be solved.
# Machine 161: Can be solved with 130 tokens.
# Machine 162: Cannot be solved.
# Machine 163: Can be solved with 63 tokens.
# Machine 164: Can be solved with 42 tokens.
# Machine 165: Can be solved with 245 tokens.
# Machine 166: Can be solved with 129 tokens.
# Machine 167: Can be solved with 222 tokens.
# Machine 168: Can be solved with 147 tokens.
# Machine 169: Can be solved with 351 tokens.
# Machine 170: Cannot be solved.
# Machine 171: Can be solved with 213 tokens.
# Machine 172: Cannot be solved.
# Machine 173: Can be solved with 214 tokens.
# Machine 174: Cannot be solved.
# Machine 175: Can be solved with 354 tokens.
# Machine 176: Can be solved with 146 tokens.
# Machine 177: Cannot be solved.
# Machine 178: Cannot be solved.
# Machine 179: Can be solved with 282 tokens.
# Machine 180: Can be solved with 113 tokens.
# Machine 181: Can be solved with 260 tokens.
# Machine 182: Cannot be solved.
# Machine 183: Can be solved with 126 tokens.
# Machine 184: Cannot be solved.
# Machine 185: Cannot be solved.
# Machine 186: Cannot be solved.
# Machine 187: Cannot be solved.
# Machine 188: Can be solved with 215 tokens.
# Machine 189: Cannot be solved.
# Machine 190: Cannot be solved.
# Machine 191: Can be solved with 360 tokens.
# Machine 192: Cannot be solved.
# Machine 193: Can be solved with 316 tokens.
# Machine 194: Can be solved with 328 tokens.
# Machine 195: Cannot be solved.
# Machine 196: Can be solved with 106 tokens.
# Machine 197: Can be solved with 163 tokens.
# Machine 198: Can be solved with 170 tokens.
# Machine 199: Cannot be solved.
# Machine 200: Cannot be solved.
# Machine 201: Cannot be solved.
# Machine 202: Can be solved with 269 tokens.
# Machine 203: Can be solved with 187 tokens.
# Machine 204: Cannot be solved.
# Machine 205: Can be solved with 278 tokens.
# Machine 206: Cannot be solved.
# Machine 207: Cannot be solved.
# Machine 208: Cannot be solved.
# Machine 209: Cannot be solved.
# Machine 210: Can be solved with 101 tokens.
# Machine 211: Cannot be solved.
# Machine 212: Can be solved with 327 tokens.
# Machine 213: Cannot be solved.
# Machine 214: Cannot be solved.
# Machine 215: Can be solved with 312 tokens.
# Machine 216: Cannot be solved.
# Machine 217: Can be solved with 275 tokens.
# Machine 218: Cannot be solved.
# Machine 219: Cannot be solved.
# Machine 220: Cannot be solved.
# Machine 221: Cannot be solved.
# Machine 222: Cannot be solved.
# Machine 223: Cannot be solved.
# Machine 224: Can be solved with 169 tokens.
# Machine 225: Cannot be solved.
# Machine 226: Can be solved with 167 tokens.
# Machine 227: Can be solved with 271 tokens.
# Machine 228: Can be solved with 258 tokens.
# Machine 229: Can be solved with 220 tokens.
# Machine 230: Cannot be solved.
# Machine 231: Cannot be solved.
# Machine 232: Can be solved with 97 tokens.
# Machine 233: Can be solved with 136 tokens.
# Machine 234: Cannot be solved.
# Machine 235: Can be solved with 342 tokens.
# Machine 236: Cannot be solved.
# Machine 237: Cannot be solved.
# Machine 238: Cannot be solved.
# Machine 239: Can be solved with 324 tokens.
# Machine 240: Cannot be solved.
# Machine 241: Cannot be solved.
# Machine 242: Cannot be solved.
# Machine 243: Cannot be solved.
# Machine 244: Cannot be solved.
# Machine 245: Cannot be solved.
# Machine 246: Can be solved with 165 tokens.
# Machine 247: Can be solved with 187 tokens.
# Machine 248: Cannot be solved.
# Machine 249: Cannot be solved.
# Machine 250: Cannot be solved.
# Machine 251: Can be solved with 120 tokens.
# Machine 252: Can be solved with 162 tokens.
# Machine 253: Cannot be solved.
# Machine 254: Can be solved with 190 tokens.
# Machine 255: Cannot be solved.
# Machine 256: Can be solved with 173 tokens.
# Machine 257: Cannot be solved.
# Machine 258: Cannot be solved.
# Machine 259: Can be solved with 197 tokens.
# Machine 260: Can be solved with 284 tokens.
# Machine 261: Can be solved with 115 tokens.
# Machine 262: Can be solved with 245 tokens.
# Machine 263: Cannot be solved.
# Machine 264: Cannot be solved.
# Machine 265: Cannot be solved.
# Machine 266: Cannot be solved.
# Machine 267: Can be solved with 151 tokens.
# Machine 268: Cannot be solved.
# Machine 269: Can be solved with 296 tokens.
# Machine 270: Cannot be solved.
# Machine 271: Cannot be solved.
# Machine 272: Cannot be solved.
# Machine 273: Can be solved with 113 tokens.
# Machine 274: Can be solved with 296 tokens.
# Machine 275: Can be solved with 320 tokens.
# Machine 276: Can be solved with 135 tokens.
# Machine 277: Can be solved with 51 tokens.
# Machine 278: Can be solved with 238 tokens.
# Machine 279: Cannot be solved.
# Machine 280: Cannot be solved.
# Machine 281: Can be solved with 128 tokens.
# Machine 282: Cannot be solved.
# Machine 283: Cannot be solved.
# Machine 284: Can be solved with 392 tokens.
# Machine 285: Can be solved with 221 tokens.
# Machine 286: Can be solved with 32 tokens.
# Machine 287: Can be solved with 175 tokens.
# Machine 288: Can be solved with 128 tokens.
# Machine 289: Can be solved with 274 tokens.
# Machine 290: Can be solved with 287 tokens.
# Machine 291: Cannot be solved.
# Machine 292: Cannot be solved.
# Machine 293: Cannot be solved.
# Machine 294: Cannot be solved.
# Machine 295: Can be solved with 270 tokens.
# Machine 296: Can be solved with 107 tokens.
# Machine 297: Can be solved with 362 tokens.
# Machine 298: Can be solved with 319 tokens.
# Machine 299: Cannot be solved.
# Machine 300: Can be solved with 340 tokens.
# Machine 301: Can be solved with 152 tokens.
# Machine 302: Can be solved with 267 tokens.
# Machine 303: Cannot be solved.
# Machine 304: Can be solved with 112 tokens.
# Machine 305: Can be solved with 207 tokens.
# Machine 306: Cannot be solved.
# Machine 307: Cannot be solved.
# Machine 308: Can be solved with 54 tokens.
# Machine 309: Cannot be solved.
# Machine 310: Cannot be solved.
# Machine 311: Cannot be solved.
# Machine 312: Cannot be solved.
# Machine 313: Can be solved with 257 tokens.
# Machine 314: Cannot be solved.
# Machine 315: Cannot be solved.
# Machine 316: Cannot be solved.
# Machine 317: Cannot be solved.
# Machine 318: Cannot be solved.
# Machine 319: Can be solved with 177 tokens.
# Machine 320: Can be solved with 158 tokens.
#
# Total winnable prizes: 155
# Total tokens needed: 30413
# 30413

# %% [markdown]
# ## Second star

# %%
def extended_gcd(a, b):
    """
    Extended Euclidean Algorithm
    Returns (gcd, x, y) such that a*x + b*y = gcd(a,b)
    """
    if b == 0:
        return (a, 1, 0)
    else:
        g, x1, y1 = extended_gcd(b, a % b)
        x = y1
        y = x1 - (a // b) * y1
        return (g, x, y)

def mod_inv(a, m):
    """
    Computes the modular inverse of a modulo m.
    """
    g, x, _ = extended_gcd(a, m)
    if g != 1:
        return None  # Inverse doesn't exist
    else:
        return x % m

def parse_input(input_string):
    """
    Parses the input string into a list of claw machines.
    """
    machines = []
    # Remove leading/trailing whitespace and split into lines
    lines = [line.strip() for line in input_string.strip().split('\n') if line.strip()]
    
    # Process lines in chunks of 3 (Button A, Button B, Prize)
    for i in range(0, len(lines), 3):
        a_line = lines[i]
        b_line = lines[i+1]
        prize_line = lines[i+2]
        
        # Parse Button A
        a_match = re.match(r'Button A:\s*X\+(\d+),\s*Y\+(\d+)', a_line)
        A_x = int(a_match.group(1))
        A_y = int(a_match.group(2))
        
        # Parse Button B
        b_match = re.match(r'Button B:\s*X\+(\d+),\s*Y\+(\d+)', b_line)
        B_x = int(b_match.group(1))
        B_y = int(b_match.group(2))
        
        # Parse Prize
        prize_match = re.match(r'Prize:\s*X=(\d+),\s*Y=(\d+)', prize_line)
        Prize_X = int(int(prize_match.group(1)) + 10000000000000)
        Prize_Y = int(int(prize_match.group(2)) + 10000000000000)
        
        machine = {
            'button_a': {'x': A_x, 'y': A_y},
            'button_b': {'x': B_x, 'y': B_y},
            'prize': {'x': Prize_X, 'y': Prize_Y}
        }
        
        machines.append(machine)
    
    return machines

def find_min_tokens(machine):
    """
    For a given machine, find the minimal tokens required to win the prize.
    """
    A_x = machine['button_a']['x']
    A_y = machine['button_a']['y']
    B_x = machine['button_b']['x']
    B_y = machine['button_b']['y']
    Prize_X = machine['prize']['x']
    Prize_Y = machine['prize']['y']
    
    # Compute constants C and D
    C = A_y * B_x - B_y * A_x
    D = Prize_Y * B_x - B_y * Prize_X
    
    if C != 0:
        if D % C != 0:
            return None  # No integer solution for x
        x = D // C
        if x < 0:
            return None  # Negative presses not allowed
        
        # Calculate y
        rem_x = Prize_X - A_x * x
        if B_x == 0:
            if rem_x != 0:
                return None  # Cannot achieve Prize_X with current x
            y = 0
        else:
            if rem_x % B_x != 0:
                return None  # y must be integer
            y = rem_x // B_x
            if y < 0:
                return None  # Negative presses not allowed
        
        return 3 * x + y  # Total tokens
    
    else:
        if D != 0:
            return None  # No solution exists
        
        # Solve A_x * x + B_x * y = Prize_X
        g = gcd(A_x, B_x)
        if Prize_X % g != 0:
            return None  # No solution exists
        
        # Simplify the equation
        A_x_g = A_x // g
        B_x_g = B_x // g
        Prize_X_g = Prize_X // g
        
        # Find modular inverse of A_x_g mod B_x_g
        inv = mod_inv(A_x_g, B_x_g)
        if inv is None:
            return None  # No inverse exists, hence no solution
        
        # Particular solution
        x0 = (Prize_X_g * inv) % B_x_g
        y0 = (Prize_X - A_x * x0) // B_x
        
        if y0 < 0:
            return None  # Negative presses not allowed
        
        if A_x_g == 0:
            # A_x_g is zero, which means B_x_g must be positive
            # y = Prize_X // B_x
            return 3 * x0 + y0  # Minimal tokens by maximizing y
        
        # General solution: x = x0 + k * B_x_g, y = y0 - k * A_x_g
        # Find the maximum k such that y >= 0
        k_max = y0 // A_x_g
        
        # Two candidates: k =0 and k =k_max
        # Compute tokens for k=0
        tokens_k0 = 3 * x0 + y0
        
        # Compute tokens for k=k_max
        x_kmax = x0 + k_max * B_x_g
        y_kmax = y0 - k_max * A_x_g
        tokens_kmax = 3 * x_kmax + y_kmax
        
        # Return the minimal tokens
        return min(tokens_k0, tokens_kmax)

def calculate_min_tokens(input_string):
    """
    Processes all claw machines and calculates the total minimal tokens required
    to win all possible prizes.
    """
    machines = parse_input(input_string)
    total_tokens = 0
    winnable_prizes = 0
    
    for idx, machine in enumerate(machines, 1):
        min_tokens = find_min_tokens(machine)
        if min_tokens is not None:
            total_tokens += min_tokens
            winnable_prizes += 1
            print(f"Machine {idx}: Can be solved with {min_tokens} tokens.")
        else:
            print(f"Machine {idx}: Cannot be solved.")
    
    print(f"\nTotal winnable prizes: {winnable_prizes}")
    print(f"Total tokens needed: {total_tokens}")
    
    return total_tokens

# %%
input_string = """
Button A: X+94, Y+34
Button B: X+22, Y+67
Prize: X=8400, Y=5400

Button A: X+26, Y+66
Button B: X+67, Y+21
Prize: X=12748, Y=12176

Button A: X+17, Y+86
Button B: X+84, Y+37
Prize: X=7870, Y=6450

Button A: X+69, Y+23
Button B: X+27, Y+71
Prize: X=18641, Y=10279
"""

calculate_min_tokens(input_string)
# Out:
# Machine 1: Cannot be solved.
# Machine 2: Can be solved with 459236326669 tokens.
# Machine 3: Cannot be solved.
# Machine 4: Can be solved with 416082282239 tokens.
#
# Total winnable prizes: 2
# Total tokens needed: 875318608908
# 875318608908

# %%
calculate_min_tokens(buttons_config)
# Out:
# Machine 1: Cannot be solved.
# Machine 2: Cannot be solved.
# Machine 3: Cannot be solved.
# Machine 4: Cannot be solved.
# Machine 5: Can be solved with 678670359956 tokens.
# Machine 6: Cannot be solved.
# Machine 7: Can be solved with 434633812590 tokens.
# Machine 8: Can be solved with 648479428193 tokens.
# Machine 9: Cannot be solved.
# Machine 10: Cannot be solved.
# Machine 11: Can be solved with 539237177174 tokens.
# Machine 12: Cannot be solved.
# Machine 13: Can be solved with 520215633617 tokens.
# Machine 14: Can be solved with 779342724510 tokens.
# Machine 15: Can be solved with 445462114658 tokens.
# Machine 16: Cannot be solved.
# Machine 17: Can be solved with 517448857443 tokens.
# Machine 18: Can be solved with 450781968805 tokens.
# Machine 19: Can be solved with 586972083287 tokens.
# Machine 20: Cannot be solved.
# Machine 21: Cannot be solved.
# Machine 22: Cannot be solved.
# Machine 23: Cannot be solved.
# Machine 24: Can be solved with 428180990016 tokens.
# Machine 25: Cannot be solved.
# Machine 26: Cannot be solved.
# Machine 27: Can be solved with 415472779619 tokens.
# Machine 28: Can be solved with 492642354881 tokens.
# Machine 29: Cannot be solved.
# Machine 30: Cannot be solved.
# Machine 31: Cannot be solved.
# Machine 32: Can be solved with 529994177151 tokens.
# Machine 33: Cannot be solved.
# Machine 34: Cannot be solved.
# Machine 35: Cannot be solved.
# Machine 36: Can be solved with 580399620205 tokens.
# Machine 37: Cannot be solved.
# Machine 38: Can be solved with 494134376550 tokens.
# Machine 39: Can be solved with 537301894394 tokens.
# Machine 40: Cannot be solved.
# Machine 41: Cannot be solved.
# Machine 42: Cannot be solved.
# Machine 43: Can be solved with 953800300019 tokens.
# Machine 44: Cannot be solved.
# Machine 45: Cannot be solved.
# Machine 46: Cannot be solved.
# Machine 47: Can be solved with 718654435732 tokens.
# Machine 48: Can be solved with 494241842571 tokens.
# Machine 49: Cannot be solved.
# Machine 50: Can be solved with 448154657781 tokens.
# Machine 51: Cannot be solved.
# Machine 52: Can be solved with 425531915006 tokens.
# Machine 53: Cannot be solved.
# Machine 54: Cannot be solved.
# Machine 55: Cannot be solved.
# Machine 56: Cannot be solved.
# Machine 57: Can be solved with 445682452095 tokens.
# Machine 58: Can be solved with 684931507635 tokens.
# Machine 59: Cannot be solved.
# Machine 60: Cannot be solved.
# Machine 61: Cannot be solved.
# Machine 62: Can be solved with 440677966266 tokens.
# Machine 63: Can be solved with 477157361311 tokens.
# Machine 64: Can be solved with 683060109855 tokens.
# Machine 65: Cannot be solved.
# Machine 66: Can be solved with 414468726643 tokens.
# Machine 67: Can be solved with 475374732370 tokens.
# Machine 68: Cannot be solved.
# Machine 69: Can be solved with 505394662840 tokens.
# Machine 70: Can be solved with 513225425277 tokens.
# Machine 71: Cannot be solved.
# Machine 72: Cannot be solved.
# Machine 73: Cannot be solved.
# Machine 74: Can be solved with 532511211851 tokens.
# Machine 75: Cannot be solved.
# Machine 76: Can be solved with 501347709365 tokens.
# Machine 77: Can be solved with 487149980964 tokens.
# Machine 78: Cannot be solved.
# Machine 79: Can be solved with 464081373950 tokens.
# Machine 80: Cannot be solved.
# Machine 81: Cannot be solved.
# Machine 82: Can be solved with 529026218081 tokens.
# Machine 83: Cannot be solved.
# Machine 84: Can be solved with 505366727519 tokens.
# Machine 85: Cannot be solved.
# Machine 86: Cannot be solved.
# Machine 87: Can be solved with 876865673146 tokens.
# Machine 88: Cannot be solved.
# Machine 89: Cannot be solved.
# Machine 90: Can be solved with 432456531609 tokens.
# Machine 91: Can be solved with 546383648133 tokens.
# Machine 92: Can be solved with 558464224513 tokens.
# Machine 93: Can be solved with 485093481887 tokens.
# Machine 94: Can be solved with 747663551833 tokens.
# Machine 95: Can be solved with 481870229785 tokens.
# Machine 96: Can be solved with 1022099448450 tokens.
# Machine 97: Can be solved with 526544822394 tokens.
# Machine 98: Cannot be solved.
# Machine 99: Can be solved with 537634408474 tokens.
# Machine 100: Cannot be solved.
# Machine 101: Cannot be solved.
# Machine 102: Can be solved with 438047559909 tokens.
# Machine 103: Can be solved with 711043874016 tokens.
# Machine 104: Can be solved with 459946339875 tokens.
# Machine 105: Can be solved with 479225684719 tokens.
# Machine 106: Cannot be solved.
# Machine 107: Can be solved with 595514308944 tokens.
# Machine 108: Can be solved with 513880685914 tokens.
# Machine 109: Cannot be solved.
# Machine 110: Can be solved with 469656992239 tokens.
# Machine 111: Cannot be solved.
# Machine 112: Can be solved with 608446671446 tokens.
# Machine 113: Can be solved with 585975024619 tokens.
# Machine 114: Can be solved with 589543937907 tokens.
# Machine 115: Can be solved with 581162324910 tokens.
# Machine 116: Can be solved with 425870295880 tokens.
# Machine 117: Cannot be solved.
# Machine 118: Cannot be solved.
# Machine 119: Can be solved with 525105404836 tokens.
# Machine 120: Can be solved with 454266421881 tokens.
# Machine 121: Can be solved with 843373494296 tokens.
# Machine 122: Cannot be solved.
# Machine 123: Cannot be solved.
# Machine 124: Can be solved with 428247305895 tokens.
# Machine 125: Cannot be solved.
# Machine 126: Can be solved with 414291144527 tokens.
# Machine 127: Cannot be solved.
# Machine 128: Cannot be solved.
# Machine 129: Can be solved with 656146179963 tokens.
# Machine 130: Can be solved with 539093181489 tokens.
# Machine 131: Can be solved with 413885180843 tokens.
# Machine 132: Can be solved with 493579454423 tokens.
# Machine 133: Can be solved with 441988950783 tokens.
# Machine 134: Cannot be solved.
# Machine 135: Cannot be solved.
# Machine 136: Can be solved with 603975536063 tokens.
# Machine 137: Can be solved with 557553957457 tokens.
# Machine 138: Can be solved with 601265823127 tokens.
# Machine 139: Cannot be solved.
# Machine 140: Cannot be solved.
# Machine 141: Can be solved with 434508816732 tokens.
# Machine 142: Cannot be solved.
# Machine 143: Can be solved with 622119816337 tokens.
# Machine 144: Cannot be solved.
# Machine 145: Can be solved with 528946273549 tokens.
# Machine 146: Can be solved with 957661290735 tokens.
# Machine 147: Cannot be solved.
# Machine 148: Cannot be solved.
# Machine 149: Can be solved with 734355045003 tokens.
# Machine 150: Cannot be solved.
# Machine 151: Cannot be solved.
# Machine 152: Can be solved with 646525679875 tokens.
# Machine 153: Can be solved with 434412266544 tokens.
# Machine 154: Can be solved with 682897862947 tokens.
# Machine 155: Cannot be solved.
# Machine 156: Can be solved with 509000620980 tokens.
# Machine 157: Cannot be solved.
# Machine 158: Cannot be solved.
# Machine 159: Can be solved with 425422860539 tokens.
# Machine 160: Can be solved with 693983020550 tokens.
# Machine 161: Cannot be solved.
# Machine 162: Can be solved with 520191649729 tokens.
# Machine 163: Cannot be solved.
# Machine 164: Cannot be solved.
# Machine 165: Cannot be solved.
# Machine 166: Cannot be solved.
# Machine 167: Cannot be solved.
# Machine 168: Cannot be solved.
# Machine 169: Cannot be solved.
# Machine 170: Can be solved with 444177671148 tokens.
# Machine 171: Cannot be solved.
# Machine 172: Can be solved with 609911055370 tokens.
# Machine 173: Cannot be solved.
# Machine 174: Can be solved with 454165506358 tokens.
# Machine 175: Cannot be solved.
# Machine 176: Cannot be solved.
# Machine 177: Can be solved with 601646612087 tokens.
# Machine 178: Can be solved with 447127937986 tokens.
# Machine 179: Cannot be solved.
# Machine 180: Cannot be solved.
# Machine 181: Cannot be solved.
# Machine 182: Can be solved with 740469208840 tokens.
# Machine 183: Cannot be solved.
# Machine 184: Can be solved with 561797753352 tokens.
# Machine 185: Can be solved with 420733030295 tokens.
# Machine 186: Can be solved with 417543860045 tokens.
# Machine 187: Can be solved with 566945077387 tokens.
# Machine 188: Cannot be solved.
# Machine 189: Can be solved with 692389007142 tokens.
# Machine 190: Can be solved with 472279261456 tokens.
# Machine 191: Cannot be solved.
# Machine 192: Can be solved with 526315790433 tokens.
# Machine 193: Cannot be solved.
# Machine 194: Cannot be solved.
# Machine 195: Can be solved with 925170068744 tokens.
# Machine 196: Cannot be solved.
# Machine 197: Cannot be solved.
# Machine 198: Cannot be solved.
# Machine 199: Can be solved with 632911392886 tokens.
# Machine 200: Can be solved with 556167400735 tokens.
# Machine 201: Can be solved with 599337749389 tokens.
# Machine 202: Cannot be solved.
# Machine 203: Cannot be solved.
# Machine 204: Can be solved with 458135861744 tokens.
# Machine 205: Cannot be solved.
# Machine 206: Can be solved with 557939914792 tokens.
# Machine 207: Can be solved with 621788284679 tokens.
# Machine 208: Can be solved with 512654121025 tokens.
# Machine 209: Can be solved with 447019868332 tokens.
# Machine 210: Cannot be solved.
# Machine 211: Can be solved with 724637681216 tokens.
# Machine 212: Cannot be solved.
# Machine 213: Can be solved with 492196879377 tokens.
# Machine 214: Can be solved with 418555982735 tokens.
# Machine 215: Cannot be solved.
# Machine 216: Can be solved with 617696160797 tokens.
# Machine 217: Cannot be solved.
# Machine 218: Can be solved with 618982119159 tokens.
# Machine 219: Can be solved with 549148819544 tokens.
# Machine 220: Can be solved with 553160920238 tokens.
# Machine 221: Can be solved with 457902511921 tokens.
# Machine 222: Can be solved with 518460330828 tokens.
# Machine 223: Can be solved with 547736782144 tokens.
# Machine 224: Cannot be solved.
# Machine 225: Can be solved with 784313727099 tokens.
# Machine 226: Cannot be solved.
# Machine 227: Cannot be solved.
# Machine 228: Cannot be solved.
# Machine 229: Cannot be solved.
# Machine 230: Can be solved with 431266846857 tokens.
# Machine 231: Can be solved with 478723404407 tokens.
# Machine 232: Cannot be solved.
# Machine 233: Cannot be solved.
# Machine 234: Can be solved with 632215503933 tokens.
# Machine 235: Cannot be solved.
# Machine 236: Can be solved with 591397849716 tokens.
# Machine 237: Can be solved with 521739131594 tokens.
# Machine 238: Can be solved with 486150368229 tokens.
# Machine 239: Cannot be solved.
# Machine 240: Can be solved with 404006678345 tokens.
# Machine 241: Can be solved with 448807854244 tokens.
# Machine 242: Can be solved with 654205607490 tokens.
# Machine 243: Can be solved with 450177036150 tokens.
# Machine 244: Can be solved with 591286307634 tokens.
# Machine 245: Can be solved with 433727631558 tokens.
# Machine 246: Cannot be solved.
# Machine 247: Cannot be solved.
# Machine 248: Can be solved with 675587467842 tokens.
# Machine 249: Can be solved with 527049637753 tokens.
# Machine 250: Can be solved with 902111324907 tokens.
# Machine 251: Cannot be solved.
# Machine 252: Cannot be solved.
# Machine 253: Can be solved with 557065217596 tokens.
# Machine 254: Cannot be solved.
# Machine 255: Can be solved with 559186638219 tokens.
# Machine 256: Cannot be solved.
# Machine 257: Can be solved with 1030383092132 tokens.
# Machine 258: Can be solved with 566637757171 tokens.
# Machine 259: Cannot be solved.
# Machine 260: Cannot be solved.
# Machine 261: Cannot be solved.
# Machine 262: Cannot be solved.
# Machine 263: Can be solved with 580847724197 tokens.
# Machine 264: Can be solved with 631533102269 tokens.
# Machine 265: Can be solved with 488721804810 tokens.
# Machine 266: Can be solved with 617977529526 tokens.
# Machine 267: Cannot be solved.
# Machine 268: Can be solved with 530077427373 tokens.
# Machine 269: Cannot be solved.
# Machine 270: Can be solved with 536774783668 tokens.
# Machine 271: Can be solved with 442338073615 tokens.
# Machine 272: Can be solved with 664531625636 tokens.
# Machine 273: Cannot be solved.
# Machine 274: Cannot be solved.
# Machine 275: Cannot be solved.
# Machine 276: Cannot be solved.
# Machine 277: Cannot be solved.
# Machine 278: Cannot be solved.
# Machine 279: Can be solved with 485564304703 tokens.
# Machine 280: Can be solved with 526315789496 tokens.
# Machine 281: Cannot be solved.
# Machine 282: Can be solved with 459770115636 tokens.
# Machine 283: Can be solved with 418071477122 tokens.
# Machine 284: Cannot be solved.
# Machine 285: Cannot be solved.
# Machine 286: Cannot be solved.
# Machine 287: Cannot be solved.
# Machine 288: Cannot be solved.
# Machine 289: Cannot be solved.
# Machine 290: Cannot be solved.
# Machine 291: Can be solved with 457665903874 tokens.
# Machine 292: Can be solved with 804597702674 tokens.
# Machine 293: Can be solved with 487246566596 tokens.
# Machine 294: Can be solved with 460556316451 tokens.
# Machine 295: Cannot be solved.
# Machine 296: Cannot be solved.
# Machine 297: Cannot be solved.
# Machine 298: Cannot be solved.
# Machine 299: Can be solved with 442078090343 tokens.
# Machine 300: Cannot be solved.
# Machine 301: Cannot be solved.
# Machine 302: Cannot be solved.
# Machine 303: Can be solved with 636973180584 tokens.
# Machine 304: Cannot be solved.
# Machine 305: Cannot be solved.
# Machine 306: Can be solved with 464559387769 tokens.
# Machine 307: Can be solved with 604133545960 tokens.
# Machine 308: Cannot be solved.
# Machine 309: Can be solved with 493827160760 tokens.
# Machine 310: Can be solved with 605311921004 tokens.
# Machine 311: Can be solved with 679214403500 tokens.
# Machine 312: Can be solved with 872540634736 tokens.
# Machine 313: Cannot be solved.
# Machine 314: Can be solved with 731112917817 tokens.
# Machine 315: Can be solved with 1067961166624 tokens.
# Machine 316: Can be solved with 482258871001 tokens.
# Machine 317: Can be solved with 531370039389 tokens.
# Machine 318: Can be solved with 516877638126 tokens.
# Machine 319: Cannot be solved.
# Machine 320: Cannot be solved.
#
# Total winnable prizes: 165
# Total tokens needed: 92827349540204
# 92827349540204
